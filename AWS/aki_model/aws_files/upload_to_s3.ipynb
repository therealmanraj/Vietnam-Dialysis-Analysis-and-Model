# %%
import boto3

AWS_REGION          = "ca-central-1"                      
S3_BUCKET           = "my-aki-model-bucket"               
LOCAL_MODAL_PATH    = "/Users/manraj/Documents/GitHub/Vietnam-Dialysis-Analysis-and-Model/AWS/aki_model/xgb_aki_model.tar.gz"             
S3_KEY              = "models/xgb_aki_model.tar.gz"      

s3 = boto3.client("s3", region_name=AWS_REGION)
s3.upload_file(Filename=LOCAL_MODAL_PATH, Bucket=S3_BUCKET, Key=S3_KEY)

print(f"✅ Uploaded {LOCAL_MODAL_PATH} → s3://{S3_BUCKET}/{S3_KEY}")
# Out:
# ✅ Uploaded /Users/manraj/Documents/GitHub/Vietnam-Dialysis-Analysis-and-Model/AWS/aki_model/xgb_aki_model.tar.gz → s3://my-aki-model-bucket/models/xgb_aki_model.tar.gz
